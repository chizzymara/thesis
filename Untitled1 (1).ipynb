# %%
import pandas as pd
import os
import numpy as np
import re

# %%
df_hostel=pd.read_csv(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/torino hostels.csv')
df_dataset=pd.read_excel(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/dataset selected.xlsx')
df_university= pd.read_excel(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/university selected.xlsx')

# %%
df_hostel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Provincia                        50 non-null     object
#  1   Comune                           50 non-null     object
#  2   Cap                              50 non-null     int64
#  3   DenominazioneStruttura           50 non-null     object
#  4   Indirizzo                        50 non-null     object
#  5   NroCivico                        50 non-null     object
#  6   Telefono                         50 non-null     object
#  7   RecapitiFax                      39 non-null     float64
#  8   EMail                            49 non-null     object
#  9   SitoWeb                          34 non-null     object
#  10  DistanzeParcheggioEsternoM       35 non-null     object
#  11  DistanzeStazioneFerroviariaKm    45 non-null     object
# ...

# %%
df_hostel.head(53)
# Out:
#    Provincia  Comune    Cap  \
# 0     TORINO  TORINO  10100
# 1     TORINO  TORINO  10100
# 2     TORINO  TORINO  10100
# 3     TORINO  TORINO  10100
# 4     TORINO  TORINO  10100
# 5     TORINO  TORINO  10100
# 6     TORINO  TORINO  10100
# 7     TORINO  TORINO  10100
# 8     TORINO  TORINO  10100
# 9     TORINO  TORINO  10100
# 10    TORINO  TORINO  10100
# 11    TORINO  TORINO  10100
# 12    TORINO  TORINO  10100
# 13    TORINO  TORINO  10100
# 14    TORINO  TORINO  10100
# 15    TORINO  TORINO  10100
# 16    TORINO  TORINO  10100
# 17    TORINO  TORINO  10100
# 18    TORINO  TORINO  10100
# 19    TORINO  TORINO  10100
# 20    TORINO  TORINO  10100
# 21    TORINO  TORINO  10100
# 22    TORINO  TORINO  10100
# 23    TORINO  TORINO  10100
# 24    TORINO  TORINO  10100
# 25    TORINO  TORINO  10100
# 26    TORINO  TORINO  10100
# 27    TORINO  TORINO  10100
# 28    TORINO  TORINO  10100
# 29    TORINO  TORINO  10100
# 30    TORINO  TORINO  10100
# 31    TORINO  TORINO  10100
# ...

# %%
df_hostel.isnull().sum()
# Out:
# Provincia                           0
# Comune                              0
# Cap                                 0
# DenominazioneStruttura              0
# Indirizzo                           0
# NroCivico                           0
# Telefono                            0
# RecapitiFax                        11
# EMail                               1
# SitoWeb                            16
# DistanzeParcheggioEsternoM         15
# DistanzeStazioneFerroviariaKm       5
# DistanzeNomeStazioneFerroviaria     5
# dtype: int64

# %% [markdown]
# completeness
# total missing data=53
# expected total records(based on the size of the dataframe)=650

# %%
df_hostel['DistanzeNomeStazioneFerroviaria'].value_counts()
# Out:
# PORTA SUSA            14
# PORTA NUOVA           11
# FS Porta Nuova         4
# PORTA NUOVA / SUSA     3
# Porta Nuova            3
# FS Porta Susa          2
# FS PORTA NUOVA         2
# Fs Porta Susa          1
# fs porta susa          1
# FS porta nuova         1
# Lingotto               1
# GTT DORA               1
# FS                     1
# Name: DistanzeNomeStazioneFerroviaria, dtype: int64

# %%
df_hostel['DistanzeNomeStazioneFerroviaria'].map(type)
# Out:
# 0     <class 'float'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
# 5       <class 'str'>
# 6       <class 'str'>
# 7       <class 'str'>
# 8       <class 'str'>
# 9       <class 'str'>
# 10      <class 'str'>
# 11    <class 'float'>
# 12      <class 'str'>
# 13      <class 'str'>
# 14      <class 'str'>
# 15    <class 'float'>
# 16      <class 'str'>
# 17      <class 'str'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20      <class 'str'>
# 21      <class 'str'>
# 22      <class 'str'>
# 23      <class 'str'>
# 24      <class 'str'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27      <class 'str'>
# 28      <class 'str'>
# 29    <class 'float'>
# 30      <class 'str'>
# 31      <class 'str'>
# 32      <class 'str'>
# 33      <class 'str'>
# 34      <class 'str'>
# 35      <class 'str'>
# 36      <class 'str'>
# 37    <class 'float'>
# 38      <class 'str'>
# 39      <class 'str'>
# 40      <class 'str'>
# ...

# %%
df_hostel['DistanzeParcheggioEsternoM'].value_counts()
# Out:
# 10        4
# 50 mt     3
# 10 mt     3
# 0 m       3
# 20 mt     3
# 100 mt    2
# 500 mt    2
# 30 m      2
# 15 mt     2
# 200 mt    1
# 250 MT    1
# 50        1
# 10 MT     1
# 0         1
# 300 mt    1
# 5 MT      1
# 100       1
# 1         1
# 30 MT     1
# 30 mt     1
# Name: DistanzeParcheggioEsternoM, dtype: int64

# %%
df_hostel['DistanzeParcheggioEsternoM'].map(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2     <class 'float'>
# 3       <class 'str'>
# 4       <class 'str'>
# 5     <class 'float'>
# 6     <class 'float'>
# 7     <class 'float'>
# 8       <class 'str'>
# 9     <class 'float'>
# 10      <class 'str'>
# 11      <class 'str'>
# 12      <class 'str'>
# 13      <class 'str'>
# 14      <class 'str'>
# 15      <class 'str'>
# 16      <class 'str'>
# 17      <class 'str'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20      <class 'str'>
# 21      <class 'str'>
# 22    <class 'float'>
# 23      <class 'str'>
# 24      <class 'str'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27    <class 'float'>
# 28      <class 'str'>
# 29    <class 'float'>
# 30      <class 'str'>
# 31    <class 'float'>
# 32    <class 'float'>
# 33      <class 'str'>
# 34      <class 'str'>
# 35    <class 'float'>
# 36      <class 'str'>
# 37      <class 'str'>
# 38    <class 'float'>
# 39    <class 'float'>
# 40      <class 'str'>
# ...

# %%
df_hostel['DistanzeStazioneFerroviariaKm'].value_counts()
# Out:
# 2 km       5
# 1 Km       3
# 6 km       2
# 3 Km       2
# 3,2 km     2
# 2 Km       2
# 1,9 km     2
# 1 km       2
# 0,6 km     2
# 4 km       2
# 3,3 km     1
# 1,5 Km     1
# 0,2 km     1
# 2,4        1
# 5 km       1
# 700 m      1
# 0,8        1
# 6 Km       1
# 6,5 Km     1
# 0,85 km    1
# 0,5        1
# 0,2 KM     1
# 0,5 km     1
# km 3,7     1
# 4          1
# 2,5 km     1
# 0,8 Km     1
# 1,7 KM     1
# 2 KM       1
# 3,5 Km     1
# 5,5 KM     1
# Name: DistanzeStazioneFerroviariaKm, dtype: int64

# %%
df_hostel['DistanzeStazioneFerroviariaKm'].map(type)
# Out:
# 0     <class 'float'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
# 5       <class 'str'>
# 6       <class 'str'>
# 7       <class 'str'>
# 8       <class 'str'>
# 9       <class 'str'>
# 10      <class 'str'>
# 11    <class 'float'>
# 12      <class 'str'>
# 13      <class 'str'>
# 14      <class 'str'>
# 15    <class 'float'>
# 16      <class 'str'>
# 17      <class 'str'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20      <class 'str'>
# 21      <class 'str'>
# 22      <class 'str'>
# 23      <class 'str'>
# 24      <class 'str'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27      <class 'str'>
# 28      <class 'str'>
# 29    <class 'float'>
# 30      <class 'str'>
# 31      <class 'str'>
# 32      <class 'str'>
# 33      <class 'str'>
# 34      <class 'str'>
# 35      <class 'str'>
# 36      <class 'str'>
# 37    <class 'float'>
# 38      <class 'str'>
# 39      <class 'str'>
# 40      <class 'str'>
# ...

# %%
 df_hostel['NroCivico'].map(type)
# Out:
# 0     <class 'str'>
# 1     <class 'str'>
# 2     <class 'str'>
# 3     <class 'str'>
# 4     <class 'str'>
# 5     <class 'str'>
# 6     <class 'str'>
# 7     <class 'str'>
# 8     <class 'str'>
# 9     <class 'str'>
# 10    <class 'str'>
# 11    <class 'str'>
# 12    <class 'str'>
# 13    <class 'str'>
# 14    <class 'str'>
# 15    <class 'str'>
# 16    <class 'str'>
# 17    <class 'str'>
# 18    <class 'str'>
# 19    <class 'str'>
# 20    <class 'str'>
# 21    <class 'str'>
# 22    <class 'str'>
# 23    <class 'str'>
# 24    <class 'str'>
# 25    <class 'str'>
# 26    <class 'str'>
# 27    <class 'str'>
# 28    <class 'str'>
# 29    <class 'str'>
# 30    <class 'str'>
# 31    <class 'str'>
# 32    <class 'str'>
# 33    <class 'str'>
# 34    <class 'str'>
# 35    <class 'str'>
# 36    <class 'str'>
# 37    <class 'str'>
# 38    <class 'str'>
# 39    <class 'str'>
# 40    <class 'str'>
# 41    <class 'str'>
# 42    <class 'str'>
# 43    <class 'str'>
# 44    <class 'str'>
# ...

# %%
 df_hostel['Telefono'].map(type)
# Out:
# 0     <class 'str'>
# 1     <class 'str'>
# 2     <class 'str'>
# 3     <class 'str'>
# 4     <class 'str'>
# 5     <class 'str'>
# 6     <class 'str'>
# 7     <class 'str'>
# 8     <class 'str'>
# 9     <class 'str'>
# 10    <class 'str'>
# 11    <class 'str'>
# 12    <class 'str'>
# 13    <class 'str'>
# 14    <class 'str'>
# 15    <class 'str'>
# 16    <class 'str'>
# 17    <class 'str'>
# 18    <class 'str'>
# 19    <class 'str'>
# 20    <class 'str'>
# 21    <class 'str'>
# 22    <class 'str'>
# 23    <class 'str'>
# 24    <class 'str'>
# 25    <class 'str'>
# 26    <class 'str'>
# 27    <class 'str'>
# 28    <class 'str'>
# 29    <class 'str'>
# 30    <class 'str'>
# 31    <class 'str'>
# 32    <class 'str'>
# 33    <class 'str'>
# 34    <class 'str'>
# 35    <class 'str'>
# 36    <class 'str'>
# 37    <class 'str'>
# 38    <class 'str'>
# 39    <class 'str'>
# 40    <class 'str'>
# 41    <class 'str'>
# 42    <class 'str'>
# 43    <class 'str'>
# 44    <class 'str'>
# ...

# %% [markdown]
# effiency problems will be checked as numbers stored as strings, for this we observe the dtypes of the columns and further investigate for columns that should have numeric data.
# total numbers stored as strings=226

# %% [markdown]
# inaccurate data includes 50 sematic errors (cap column),1 sematic error (FS) in DistanzeNomeStazioneFerroviaria column, 42  non unifrom standards in DistanzeNomeStazioneFerroviaria,
# 19 records in DistanzeParcheggioEsternoM and 41 in DistanzeStazioneFerroviariaKm with embedded unit of measurements
# total inaccurate data in hostel data = 153

# %% [markdown]
# consistency problems include 3 in DistanzeStazioneFerroviariaKm column ('700 m' , 'km 3,7' ), 42 non uniform standard representation of porta susa and porta nouva in DistanzeNomeStazioneFerroviaria' column, 6 non uniform units of measurements in DistanzeParcheggioEsternoM column
# total inconsistent records in hostel =51

# %%
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country(or dependent territory)  30 non-null     object
#  1   Population                       30 non-null     int64
#  2   % of worldpopulation             30 non-null     float64
#  3   Total Area                       30 non-null     object
#  4   Percentage Water                 30 non-null     object
#  5   Total Nominal GDP                30 non-null     object
#  6   Per Capita GDP                   30 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.8+ KB

# %%
df_dataset.head(30)
# Out:
#    Country(or dependent territory)  Population  % of worldpopulation  \
# 0                    China[Note 2]  1394350000               0.18200
# 1                    India[Note 3]  1337630000               0.17500
# 2            United States[Note 4]   327918000               0.04280
# 3                           Brazil   209650000               0.02740
# 4                         Pakistan   202169000               0.02640
# 5                          Nigeria   193392517               0.02530
# 6                       Bangladesh   165278000               0.02160
# 7                   Russia[Note 5]   146877088               0.01920
# 8                            Japan   126420000               0.01650
# 9                           Mexico   124737789               0.01630
# 10                        Ethiopia   107534882               0.01400
# 11                     Philippines   106540000               0.01390
# 12                           Egypt    97639400               0.01280
# ...

# %%
df_dataset.isnull().sum()
# Out:
# Country(or dependent territory)    0
# Population                         0
# % of worldpopulation               0
# Total Area                         0
# Percentage Water                   0
# Total Nominal GDP                  0
# Per Capita GDP                     0
# dtype: int64

# %% [markdown]
# completeness
# total missing data=0
# expected total records(based on the size of the dataframe)=210

# %%
df_dataset['Country(or dependent territory)'].value_counts()
# Out:
#  Pakistan                  1
#  Vietnam                   1
#  Myanmar                   1
#  Philippines               1
#  Ethiopia                  1
#  China[Note 2]             1
#  India[Note 3]             1
#  Italy                     1
#  Japan                     1
#  Latvia                    1
#  France[Note 6]            1
#  Nigeria                   1
#  Iran                      1
#  Russia[Note 5]            1
#  Mexico                    1
#  Germany                   1
#  South Africa              1
#  Turkey                    1
#  United Kingdom[Note 7]    1
#  Tanzania[Note 8]          1
#  Thailand                  1
#  Bangladesh                1
#  Brazil                    1
#  Slovenia                  1
#  Kosovo[Note 17]           1
#  Guinea-Bissau             1
#  United States[Note 4]     1
#  Georgia[Note 15]          1
#  DR Congo                  1
#  Egypt                     1
# Name: Country(or dependent territory), dtype: int64

# %%
df_dataset['Percentage Water'].value_counts()
# Out:
# 6.4                                         1
# 6.4[6]                                      1
# 1.4                                         1
# 2.86                                        1
# 0.8                                         1
# 0.7                                         1
# 6.97                                        1
# 7.07                                        1
# 0.7[6]                                      1
# 9.6                                         1
# 1.3                                         1
# 0.4 (2,230 km2)                             1
# 3.32                                        1
# 2.4                                         1
# 551,695 km2 (213,011 sq mi)[V] (50th)    1
# 22.4                                        1
# 0.61[6] (inland waters)                    1
# 1.57% (1,014 km2)                           1
# 3.06                                        1
# 6.4[5]                                      1
# ...

# %% [markdown]
# inaccurate data includes 9 embedded records in Country(or dependent territory) 30 in Total Area, 12 in Percentage Water,30 in Total Nominal GDP and 30 in Per Capita GDP
# total inaccurate data in dataset =111

# %%
df_dataset.head()
# Out:
#   Country(or dependent territory)  Population  % of worldpopulation  \
# 0                   China[Note 2]  1394350000                0.1820
# 1                   India[Note 3]  1337630000                0.1750
# 2           United States[Note 4]   327918000                0.0428
# 3                          Brazil   209650000                0.0274
# 4                        Pakistan   202169000                0.0264
#
#                                         Total Area Percentage Water  \
# 0  9,596,961 km2 (3,705,407 sq mi)[g] (3rd/4th)          2.8%[h]
# 1   3,287,263[5] km2 (1,269,219 sq mi)[d] (7th)              9.6
# 2  3,796,742 sq mi (9,833,520 km2)[8] (3rd/4th)             6.97
# 3         8,515,767 km2 (3,287,956 sq mi) (5th)             0.65
# 4     881,913 km2 (340,509 sq mi)[a][18] (33rd)             2.86
#
#             Total Nominal GDP      Per Capita GDP
# 0  $14.092 trillion[16] (2nd)  $10,087[16] (71st)
# ...

# %%
df_dataset['Total Nominal GDP1'] = df_dataset['Total Nominal GDP'].str.replace(r"\(.*\)", "").str.replace(r"\[\d*\]","").str.replace("$","").str.replace("2.624 trillion ","2.624 trillion").str.replace("56.933 billion","56.933 billion").str.replace(",",".")
df_dataset['Per Capita GDP1'] = df_dataset['Per Capita GDP'].str.replace(r"\(.*\)", "").str.replace(r"\[\d*\]","").str.replace("$","")

# %%
df_dataset['Total Nominal GDP1'].unique()
# Out:
# array(['14.092 trillion ', '2.848 trillion ', '19.390 trillion ',
#        '2.139 trillion ', '304.4 billion ', '376.28 billion ',
#        '285.817 billion ', '1.719 trillion ', '5.167 trillion ',
#        '1.250 trillion ', '85.664 billion', '371.8 billion',
#        '237.073 billion ', '240.779 billion ', '40.415 billion',
#        '3.685 trillion ', '438.3 billion ', '909 billion ',
#        '514.700 billion', '2.583 trillion ', '2.624 trillion',
#        '2.181 trillion ', '371 billion ', '55.666 billion',
#        '69.322 billion ', '15.23 billion ', '56.933 billion',
#        '30.176 billion', '7.73 billion', '1.295 billion'], dtype=object)

# %% [markdown]
# for x in range(len(df_dataset['Total Nominal GDP1'])):
#     gdp = df_dataset.iloc[x]['Total Nominal GDP1']
#     if ('trillion' in df_dataset.iloc[x]['Total Nominal GDP1']):
#         gdp = re.sub(r'[^0-9.]+', '', gdp)
#         gdp = int(float(gdp) * 1000000000000)
#     elif ('billion' in df_dataset.iloc[x]['Total Nominal GDP1']):
#         gdp = re.sub(r'[^0-9.]+', '', gdp)
#         gdp = int(float(gdp) * 1000000000)
#     elif ('million' in df_dataset.iloc[x]['Total Nominal GDP1']):
#         gdp = re.sub(r'[^0-9.]+', '', gdp)
#         gdp = int(float(gdp) * 1000000)
#     else:
#         gdp = int(re.sub(r'[^0-9.]+', '', gdp))
#     df_dataset.iloc[x]['Total Nominal GDP1'] = gdp

# %% [markdown]
# df_dataset['Total Nominal GDP1'].apply(lambda x:  float(x.replace("trillion",""))*1000000000000  if 'trillion' in x  else x)
# df_dataset['Total Nominal GDP1'].apply(lambda x:  float(x.replace("billion",""))*1000000000 if 'billion' in x  else x)
# df_dataset['Total Nominal GDP1'].apply(lambda x:  float(x.replace("million",""))*1000000 if 'million' in x else x)

# %%
df_dataset.head()
# Out:
#   Country(or dependent territory)  Population  % of worldpopulation  \
# 0                   China[Note 2]  1394350000                0.1820
# 1                   India[Note 3]  1337630000                0.1750
# 2           United States[Note 4]   327918000                0.0428
# 3                          Brazil   209650000                0.0274
# 4                        Pakistan   202169000                0.0264
#
#                                         Total Area Percentage Water  \
# 0  9,596,961 km2 (3,705,407 sq mi)[g] (3rd/4th)          2.8%[h]
# 1   3,287,263[5] km2 (1,269,219 sq mi)[d] (7th)              9.6
# 2  3,796,742 sq mi (9,833,520 km2)[8] (3rd/4th)             6.97
# 3         8,515,767 km2 (3,287,956 sq mi) (5th)             0.65
# 4     881,913 km2 (340,509 sq mi)[a][18] (33rd)             2.86
#
#        Total Nominal GDP      Per Capita GDP Total Nominal GDP1  \
# 0  $14.092 trillion[16]   $10,087[16] (71st)   14.092 trillion
# ...

# %% [markdown]
# inconsistent data includes 1 inconsistent format record (69,322 billion) in per capital gdp column, 3 inconsistent data in %percentage water to calculate the per capital gdp, the nominal gdp is calculated by the population, we can check the consistency of the per capital gdp column by comparing it to a calculated gdp per capital based on the values in dataset????

# %%
df_dataset['Percentage Water'].map(type)
# Out:
# 0       <class 'str'>
# 1     <class 'float'>
# 2     <class 'float'>
# 3     <class 'float'>
# 4     <class 'float'>
# 5     <class 'float'>
# 6     <class 'float'>
# 7       <class 'str'>
# 8     <class 'float'>
# 9     <class 'float'>
# 10    <class 'float'>
# 11      <class 'str'>
# 12    <class 'float'>
# 13      <class 'str'>
# 14    <class 'float'>
# 15      <class 'str'>
# 16    <class 'float'>
# 17    <class 'float'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20    <class 'float'>
# 21    <class 'float'>
# 22    <class 'float'>
# 23      <class 'str'>
# 24    <class 'float'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27      <class 'str'>
# 28      <class 'str'>
# 29    <class 'float'>
# Name: Percentage Water, dtype: object

# %%
df_dataset['Total Nominal GDP'].map(type)
# Out:
# 0     <class 'str'>
# 1     <class 'str'>
# 2     <class 'str'>
# 3     <class 'str'>
# 4     <class 'str'>
# 5     <class 'str'>
# 6     <class 'str'>
# 7     <class 'str'>
# 8     <class 'str'>
# 9     <class 'str'>
# 10    <class 'str'>
# 11    <class 'str'>
# 12    <class 'str'>
# 13    <class 'str'>
# 14    <class 'str'>
# 15    <class 'str'>
# 16    <class 'str'>
# 17    <class 'str'>
# 18    <class 'str'>
# 19    <class 'str'>
# 20    <class 'str'>
# 21    <class 'str'>
# 22    <class 'str'>
# 23    <class 'str'>
# 24    <class 'str'>
# 25    <class 'str'>
# 26    <class 'str'>
# 27    <class 'str'>
# 28    <class 'str'>
# 29    <class 'str'>
# Name: Total Nominal GDP, dtype: object

# %%
df_dataset['Per Capita GDP'].map(type)
# Out:
# 0     <class 'str'>
# 1     <class 'str'>
# 2     <class 'str'>
# 3     <class 'str'>
# 4     <class 'str'>
# 5     <class 'str'>
# 6     <class 'str'>
# 7     <class 'str'>
# 8     <class 'str'>
# 9     <class 'str'>
# 10    <class 'str'>
# 11    <class 'str'>
# 12    <class 'str'>
# 13    <class 'str'>
# 14    <class 'str'>
# 15    <class 'str'>
# 16    <class 'str'>
# 17    <class 'str'>
# 18    <class 'str'>
# 19    <class 'str'>
# 20    <class 'str'>
# 21    <class 'str'>
# 22    <class 'str'>
# 23    <class 'str'>
# 24    <class 'str'>
# 25    <class 'str'>
# 26    <class 'str'>
# 27    <class 'str'>
# 28    <class 'str'>
# 29    <class 'str'>
# Name: Per Capita GDP, dtype: object

# %%
df_dataset['Total Area'].map(type)
# Out:
# 0     <class 'str'>
# 1     <class 'str'>
# 2     <class 'str'>
# 3     <class 'str'>
# 4     <class 'str'>
# 5     <class 'str'>
# 6     <class 'str'>
# 7     <class 'str'>
# 8     <class 'str'>
# 9     <class 'str'>
# 10    <class 'str'>
# 11    <class 'str'>
# 12    <class 'str'>
# 13    <class 'str'>
# 14    <class 'str'>
# 15    <class 'str'>
# 16    <class 'str'>
# 17    <class 'str'>
# 18    <class 'str'>
# 19    <class 'str'>
# 20    <class 'str'>
# 21    <class 'str'>
# 22    <class 'str'>
# 23    <class 'str'>
# 24    <class 'str'>
# 25    <class 'str'>
# 26    <class 'str'>
# 27    <class 'str'>
# 28    <class 'str'>
# 29    <class 'str'>
# Name: Total Area, dtype: object

# %% [markdown]
# efficiency problems for dataset.csv is a total of 12

# %%
df_university.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   university    54 non-null     object
#  1   endowment     54 non-null     object
#  2   numFaculty    36 non-null     object
#  3   numDoctoral   8 non-null      object
#  4   country       54 non-null     object
#  5   numStaff      20 non-null     float64
#  6   established   54 non-null     object
#  7   numPostgrad   50 non-null     object
#  8   numUndergrad  53 non-null     object
#  9   numStudents   42 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 4.3+ KB

# %%
df_university.isnull().sum()
# Out:
# university       0
# endowment        0
# numFaculty      18
# numDoctoral     46
# country          0
# numStaff        34
# established      0
# numPostgrad      4
# numUndergrad     1
# numStudents     12
# dtype: int64

# %%
df_university.head(55)
# Out:
#                                            university  \
# 0           %C3%89cole Polytechnique de Montr%C3%A9al
# 1           %C3%89cole Polytechnique de Montr%C3%A9al
# 2                                   Acadia University
# 3                                     Bowdoin College
# 4          California State University%2C Los Angeles
# 5                              Cape Breton University
# 6                               Confederation College
# 7                                    Defiance College
# 8                                   Durham University
# 9                                   Durham University
# 10                           East Carolina University
# 11                                   Hamilton College
# 12                             Idaho State University
# 13                             Idaho State University
# 14                             Idaho State University
# 15                             Idaho State University
# ...

# %% [markdown]
# completeness
# total missing data=115
# expected total records(based on the size of the dataframe)=540 before deduplication

# %%
df_university['university'].value_counts()
# Out:
# Idaho State University                               4
# University of the Philippines Los Ba%C3%B1os         3
# University of Delaware                               3
# University of Minnesota                              3
# University of North Carolina at Charlotte            2
# Otterbein University                                 2
# Santa Clara University College of Arts & Sciences    2
# Savonia University of Applied Sciences               2
# Washington State University                          2
# %C3%89cole Polytechnique de Montr%C3%A9al            2
# Durham University                                    2
# Lancaster University                                 2
# Rocky Mountain College                               2
# University of Milan                                  1
# Osaka University of Foreign Studies                  1
# Cape Breton University                               1
# University of Michigan                               1
# ...

# %%
#df_university.drop_duplicates() #not effective will manually remove them

# %%
df_university.drop([1,9, 13, 14,15,17,21,24,26,28,34,35,40,41,43,48,49,53],inplace=True)

# %%
df_university.reset_index(inplace=True) #deduplicated dataset with index reset

# %%
df_university.drop(["index"], axis=1, inplace=True) #drops old index

# %%
df_university.isnull().sum() #after deduplication
# Out:
# university       0
# endowment        0
# numFaculty      11
# numDoctoral     30
# country          0
# numStaff        24
# established      0
# numPostgrad      4
# numUndergrad     1
# numStudents     10
# dtype: int64

# %% [markdown]
# completeness total missing data=80 expected total records(based on the size of the dataframe)=360 #after deduplication

# %%
df_university.info() #after deduplication
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   university    36 non-null     object
#  1   endowment     36 non-null     object
#  2   numFaculty    25 non-null     object
#  3   numDoctoral   6 non-null      object
#  4   country       36 non-null     object
#  5   numStaff      12 non-null     float64
#  6   established   36 non-null     object
#  7   numPostgrad   32 non-null     object
#  8   numUndergrad  35 non-null     object
#  9   numStudents   26 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 2.9+ KB

# %%
df_university['university'].value_counts()
# Out:
# University of Central Oklahoma                       1
# Bowdoin College                                      1
# University of Northern Iowa                          1
# Defiance College                                     1
# University of Michigan                               1
# University of Toronto                                1
# University of Milan                                  1
# University of the Philippines Los Ba%C3%B1os         1
# University of Delaware                               1
# Cape Breton University                               1
# Lancaster University                                 1
# Osaka University of Foreign Studies                  1
# Smith College                                        1
# University of St. Gallen                             1
# Washington State University                          1
# Savonia University of Applied Sciences               1
# Acadia University                                    1
# ...

# %%
df_university['endowment'].unique()
# Out:
# array(['$CAD145 million', 40000000, 904200000, '$19.2 million 2011', 3400,
#        4700000, '$12.5 million.', '£61.3M', 'USD$130.0 million',
#        701670000, 40200750, 5950000, 121, 'US$  billion', 'US$70,025,283',
#        15, 16586100, '$603.6 million parent institution',
#        'approx. $100 million', 1430000000, 'U.S. $30.3 million', 17000000,
#        '$1.008 billion USD', 121000000, 'US $6.56 billion', 562000000,
#        'US$2.224 billion in 2006', 'US$105.9 million',
#        '$65.8 M http://www.nacubo.org/Images/All%20Institutions%20Listed%20by%20FY%202007%20Market%20Value%20of%20Endowment%20Assets_2007%20NES.pdf',
#        20000000, 'CHF 183 million annual budget', '₱4.46 billion',
#        'C$1.518 billion', 'US$513.4 million', 619800000], dtype=object)

# %%
df_university['numFaculty'].value_counts()
# Out:
# 933                              1
# 4210                             1
# 1325                             1
# 834                              1
# 2687                             1
# 800                              1
# 838                              1
# 1031                             1
# 488268                           1
# 1804                             1
# 3374                             1
# 239                              1
# 231                              1
# Day Course and Evening Course    1
# 1490                             1
# 6238                             1
# 86                               1
# 2551                             1
# 1304                             1
# 217                              1
# 250                              1
# 219                              1
# 5500                             1
# 285                              1
# 1280                             1
# Name: numFaculty, dtype: int64

# %%
df_university['numDoctoral'].value_counts()
# Out:
# 782              1
# 611              1
# 1355             1
# not available    1
# 817              1
# 8000             1
# Name: numDoctoral, dtype: int64

# %%
df_university['country'].value_counts()
# Out:
# United States                                               11
# Canada                                                       4
# USA                                                          3
# U.S.                                                         2
# US                                                           2
# France                                                       2
# England                                                      2
# England, UK                                                  1
# Italy                                                        1
# Philippines                                                  1
# Canada B1P 6L2                                               1
# Canada C1A 4P3 Telephone: 902-566-0439 Fax: 902-566-0795     1
# Finland                                                      1
# United States )                                              1
# U.S.A.                                                       1
# ...

# %%
df_university['numStaff'].value_counts()
# Out:
# 4795.0     1
# 18426.0    1
# 2455.0     1
# 3025.0     1
# 5354.0     1
# 14362.0    1
# 285.0      1
# 4004.0     1
# 600.0      1
# 1269.0     1
# 211.0      1
# 220.0      1
# Name: numStaff, dtype: int64

# %%
df_university['established'].value_counts()
# Out:
# 1851                                                         2
# 1873                                                         1
# 1947                                                         1
# 1909-03-06 00:00:00                                          1
# 1817                                                         1
# 1878                                                         1
# 2005                                                         1
# Founded Mar. 1921,                                           1
# 1743                                                         1
# 1951                                                         1
# 1881 - University College Liverpool                          1
# 1838 Queen's College established. Now Acadia University.     1
# Chartered in 1871; opened its doors in 1875                  1
# 1794-06-24                                                   1
# 1907-03-08 00:00:00                                          1
# ...

# %%
df_university['numPostgrad'].value_counts() #2 errors Some postdoctoral students and visiting scholars  , not available
# Out:
# 1047                                                2
# 100                                                 2
# 12732                                               1
# 66                                                  1
# 4611                                                1
# 324                                                 1
# 7046                                                1
# 3043                                                1
# 76                                                  1
# Some postdoctoral students and visiting scholars    1
# 1615                                                1
# 400                                                 1
# 6417                                                1
# 3346                                                1
# 3860                                                1
# 7448                                                1
# not available                                       1
# ...

# %%
df_university['numUndergrad'].value_counts() #1 error pre-university students; technical
# Out:
# 15251                                 1
# 15757                                 1
# 49476                                 1
# 1812                                  1
# 1491                                  1
# pre-university students; technical    1
# 3656                                  1
# 11278                                 1
# 2700                                  1
# 12892                                 1
# 11147                                 1
# 2760                                  1
# 10756                                 1
# 43141                                 1
# 900                                   1
# 14851                                 1
# 16008                                 1
# 25000                                 1
# 3929                                  1
# 1777                                  1
# 20974                                 1
# 20283                                 1
# 15380                                 1
# ...

# %%
df_university['numStudents'].value_counts() #1 error -18234
# Out:
#  8846     2
#  19391    1
#  15553    1
#  30819    1
#  16355    1
# -18234    1
#  12125    1
#  27816    1
#  1000     1
#  27393    1
#  25063    1
#  17101    1
#  20655    1
#  894      1
#  70000    1
#  62801    1
#  21160    1
#  41674    1
#  4500     1
#  4600     1
#  10688    1
#  51611    1
#  6726     1
#  3485     1
#  3168     1
# Name: numStudents, dtype: int64

# %%
df_university['numStudents'].map(type) #0
# Out:
# 0     <class 'float'>
# 1       <class 'int'>
# 2     <class 'float'>
# 3     <class 'float'>
# 4       <class 'int'>
# 5       <class 'int'>
# 6       <class 'int'>
# 7       <class 'int'>
# 8       <class 'int'>
# 9     <class 'float'>
# 10      <class 'int'>
# 11      <class 'int'>
# 12      <class 'int'>
# 13    <class 'float'>
# 14    <class 'float'>
# 15      <class 'int'>
# 16      <class 'int'>
# 17      <class 'int'>
# 18      <class 'int'>
# 19      <class 'int'>
# 20    <class 'float'>
# 21    <class 'float'>
# 22      <class 'int'>
# 23      <class 'int'>
# 24      <class 'int'>
# 25      <class 'int'>
# 26      <class 'int'>
# 27      <class 'int'>
# 28      <class 'int'>
# 29    <class 'float'>
# 30      <class 'int'>
# 31      <class 'int'>
# 32      <class 'int'>
# 33    <class 'float'>
# 34      <class 'int'>
# 35      <class 'int'>
# Name: numStudents, dtype: object

# %%
df_university['endowment'].map(type) #20
# Out:
# 0     <class 'str'>
# 1     <class 'int'>
# 2     <class 'int'>
# 3     <class 'str'>
# 4     <class 'int'>
# 5     <class 'int'>
# 6     <class 'str'>
# 7     <class 'str'>
# 8     <class 'str'>
# 9     <class 'int'>
# 10    <class 'int'>
# 11    <class 'int'>
# 12    <class 'int'>
# 13    <class 'str'>
# 14    <class 'str'>
# 15    <class 'int'>
# 16    <class 'int'>
# 17    <class 'str'>
# 18    <class 'str'>
# 19    <class 'str'>
# 20    <class 'int'>
# 21    <class 'str'>
# 22    <class 'int'>
# 23    <class 'str'>
# 24    <class 'int'>
# 25    <class 'str'>
# 26    <class 'int'>
# 27    <class 'str'>
# 28    <class 'str'>
# 29    <class 'str'>
# 30    <class 'int'>
# 31    <class 'str'>
# 32    <class 'str'>
# 33    <class 'str'>
# 34    <class 'str'>
# 35    <class 'int'>
# Name: endowment, dtype: object

# %%
df_university['numFaculty'].map(type) #1
# Out:
# 0     <class 'float'>
# 1     <class 'float'>
# 2       <class 'int'>
# 3       <class 'int'>
# 4     <class 'float'>
# 5     <class 'float'>
# 6       <class 'int'>
# 7     <class 'float'>
# 8       <class 'int'>
# 9       <class 'int'>
# 10      <class 'int'>
# 11      <class 'int'>
# 12    <class 'float'>
# 13      <class 'str'>
# 14    <class 'float'>
# 15      <class 'int'>
# 16    <class 'float'>
# 17      <class 'int'>
# 18    <class 'float'>
# 19      <class 'int'>
# 20      <class 'int'>
# 21      <class 'int'>
# 22      <class 'int'>
# 23    <class 'float'>
# 24    <class 'float'>
# 25      <class 'int'>
# 26      <class 'int'>
# 27      <class 'int'>
# 28      <class 'int'>
# 29      <class 'int'>
# 30      <class 'int'>
# 31      <class 'int'>
# 32      <class 'int'>
# 33      <class 'int'>
# 34      <class 'int'>
# 35      <class 'int'>
# Name: numFaculty, dtype: object

# %%
df_university['numDoctoral'].map(type) #1
# Out:
# 0     <class 'float'>
# 1     <class 'float'>
# 2     <class 'float'>
# 3     <class 'float'>
# 4       <class 'str'>
# 5     <class 'float'>
# 6     <class 'float'>
# 7     <class 'float'>
# 8     <class 'float'>
# 9     <class 'float'>
# 10    <class 'float'>
# 11    <class 'float'>
# 12      <class 'int'>
# 13    <class 'float'>
# 14    <class 'float'>
# 15      <class 'int'>
# 16    <class 'float'>
# 17    <class 'float'>
# 18    <class 'float'>
# 19    <class 'float'>
# 20    <class 'float'>
# 21    <class 'float'>
# 22    <class 'float'>
# 23    <class 'float'>
# 24    <class 'float'>
# 25    <class 'float'>
# 26    <class 'float'>
# 27    <class 'float'>
# 28      <class 'int'>
# 29    <class 'float'>
# 30    <class 'float'>
# 31      <class 'int'>
# 32    <class 'float'>
# 33    <class 'float'>
# 34    <class 'float'>
# 35      <class 'int'>
# Name: numDoctoral, dtype: object

# %%
df_university['numStaff'].map(type) #0
# Out:
# 0     <class 'float'>
# 1     <class 'float'>
# 2     <class 'float'>
# 3     <class 'float'>
# 4     <class 'float'>
# 5     <class 'float'>
# 6     <class 'float'>
# 7     <class 'float'>
# 8     <class 'float'>
# 9     <class 'float'>
# 10    <class 'float'>
# 11    <class 'float'>
# 12    <class 'float'>
# 13    <class 'float'>
# 14    <class 'float'>
# 15    <class 'float'>
# 16    <class 'float'>
# 17    <class 'float'>
# 18    <class 'float'>
# 19    <class 'float'>
# 20    <class 'float'>
# 21    <class 'float'>
# 22    <class 'float'>
# 23    <class 'float'>
# 24    <class 'float'>
# 25    <class 'float'>
# 26    <class 'float'>
# 27    <class 'float'>
# 28    <class 'float'>
# 29    <class 'float'>
# 30    <class 'float'>
# 31    <class 'float'>
# 32    <class 'float'>
# 33    <class 'float'>
# 34    <class 'float'>
# 35    <class 'float'>
# Name: numStaff, dtype: object

# %%
df_university['established'].map(type) #11
# Out:
# 0                   <class 'int'>
# 1                   <class 'str'>
# 2                   <class 'str'>
# 3                   <class 'int'>
# 4                   <class 'int'>
# 5                   <class 'int'>
# 6                   <class 'int'>
# 7                   <class 'int'>
# 8     <class 'datetime.datetime'>
# 9                   <class 'str'>
# 10                  <class 'int'>
# 11                  <class 'int'>
# 12                  <class 'int'>
# 13                  <class 'str'>
# 14                  <class 'int'>
# 15                  <class 'int'>
# 16                  <class 'int'>
# 17                  <class 'int'>
# 18                  <class 'str'>
# 19                  <class 'int'>
# 20                  <class 'str'>
# 21                  <class 'int'>
# 22                  <class 'int'>
# 23                  <class 'int'>
# 24                  <class 'str'>
# 25                  <class 'int'>
# 26                  <class 'int'>
# ...

# %%
df_university['numPostgrad'].map(type) #2
# Out:
# 0       <class 'int'>
# 1       <class 'int'>
# 2       <class 'str'>
# 3       <class 'int'>
# 4       <class 'int'>
# 5       <class 'str'>
# 6       <class 'int'>
# 7       <class 'int'>
# 8       <class 'int'>
# 9     <class 'float'>
# 10      <class 'int'>
# 11      <class 'int'>
# 12      <class 'int'>
# 13    <class 'float'>
# 14      <class 'int'>
# 15    <class 'float'>
# 16      <class 'int'>
# 17      <class 'int'>
# 18      <class 'int'>
# 19      <class 'int'>
# 20    <class 'float'>
# 21      <class 'int'>
# 22      <class 'int'>
# 23      <class 'int'>
# 24      <class 'int'>
# 25      <class 'int'>
# 26      <class 'int'>
# 27      <class 'int'>
# 28      <class 'int'>
# 29      <class 'int'>
# 30      <class 'int'>
# 31      <class 'int'>
# 32      <class 'int'>
# 33      <class 'int'>
# 34      <class 'int'>
# 35      <class 'int'>
# Name: numPostgrad, dtype: object

# %%
df_university['numUndergrad'].map(type) #1
# Out:
# 0       <class 'int'>
# 1       <class 'int'>
# 2       <class 'int'>
# 3       <class 'int'>
# 4       <class 'int'>
# 5       <class 'str'>
# 6       <class 'int'>
# 7       <class 'int'>
# 8       <class 'int'>
# 9       <class 'int'>
# 10      <class 'int'>
# 11      <class 'int'>
# 12      <class 'int'>
# 13    <class 'float'>
# 14      <class 'int'>
# 15      <class 'int'>
# 16      <class 'int'>
# 17      <class 'int'>
# 18      <class 'int'>
# 19      <class 'int'>
# 20      <class 'int'>
# 21      <class 'int'>
# 22      <class 'int'>
# 23      <class 'int'>
# 24      <class 'int'>
# 25      <class 'int'>
# 26      <class 'int'>
# 27      <class 'int'>
# 28      <class 'int'>
# 29      <class 'int'>
# 30      <class 'int'>
# 31      <class 'int'>
# 32      <class 'int'>
# 33      <class 'int'>
# 34      <class 'int'>
# 35      <class 'int'>
# Name: numUndergrad, dtype: object

# %% [markdown]
# inaccurate data includes 4 syntax errors in university column, 18 embeded data, 1 incorrect entry ('US$  billion') and 3 ambigious data(3400,15,121) in  endowment column , 1 incorrect entry in numFaculty column, 1 non uniform standard for missing value (not available) in the numDoctoral column, 4 embedded data in the country column('Canada B1P 6L2','Canada C1A 4P3 Telephone: 902-566-0439 Fax: 902-566-0795','England, UK' ,'United States )'), 11 non uniform standard representations in the country column, 4 embedded data in the established column, 2 incorrect data in the numPostgrad column, 1 in numUndergrad, 1 embedded data in numStudents.
# total accuracy errors in university dataset=48

# %% [markdown]
# total efficiency issues= 36

# %% [markdown]
# consistency problems include 11 non uniform standard representations in the country column 2 incorrect data in the numPostgrad column, 1 in numUndergrad, 1 embedded data in numStudents.
# 8 inconsistent date time format in the established column (yyyy and yyyy-mm-dd and yyyy-mm-dd hh:min:sec), 19 inconsistent data in the endowment column both in terms of currency and format, it also includes 18 duplicate data
# total inconsistent data= 60
