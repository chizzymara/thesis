# %%
import pandas as pd
import os
import numpy as np

# %%
print(os.path.exists('/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/IMDb movies.csv'))
# Out:
# True

# %%
df=pd.read_csv(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/IMDb movies.csv')
# Out:
# /Users/chizzymba/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
df1 = pd.read_csv(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/IMDb movies.csv')
# Out:
# /Users/chizzymba/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2= pd.read_csv(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/IMDb ratings.csv')

# %%
df2.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
df1.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
new_df = pd.merge(df1, df2, on = 'imdb_title_id')

# %%
df1.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
df.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
df.memory_usage()
# Out:
# Index                       128
# imdb_title_id            686840
# title                    686840
# original_title           686840
# year                     686840
# date_published           686840
# genre                    686840
# duration                 686840
# country                  686840
# language                 686840
# director                 686840
# writer                   686840
# production_company       686840
# actors                   686840
# description              686840
# avg_vote                 686840
# votes                    686840
# budget                   686840
# usa_gross_income         686840
# worlwide_gross_income    686840
# metascore                686840
# reviews_from_users       686840
# reviews_from_critics     686840
# dtype: int64

# %%
df[df['year']=='TV Movie 2019']
# Out:
#       imdb_title_id          title original_title           year  \
# 83917     tt8206668  Bad Education  Bad Education  TV Movie 2019
#
#       date_published                     genre  duration country language  \
# 83917  TV Movie 2019  Biography, Comedy, Crime       108     USA  English
#
#           director  ...                                             actors  \
# 83917  Cory Finley  ...  Hugh Jackman, Ray Romano, Welker White, Alliso...
#
#                                              description avg_vote  votes  \
# 83917  The beloved superintendent of New York's Rosly...      7.1  23973
#
#        budget  usa_gross_income worlwide_gross_income metascore  \
# 83917     NaN               NaN                   NaN      79.0
#
#       reviews_from_users  reviews_from_critics
# 83917              135.0                  98.0
#
# [1 rows x 22 columns]

# %%
df.drop(83917, axis=0, inplace= True)

# %%
df['year1']=df['year'].apply(np.int64)
df['year2']=df['year'].apply(np.float64)
df['year3']=df['year'].apply(np.str)
df.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# year1                      int64
# year2                    float64
# year3                     object
# dtype: object

# %%
df.memory_usage()
# Out:
# Index                    686832
# imdb_title_id            686832
# title                    686832
# original_title           686832
# year                     686832
# date_published           686832
# genre                    686832
# duration                 686832
# country                  686832
# language                 686832
# director                 686832
# writer                   686832
# production_company       686832
# actors                   686832
# description              686832
# avg_vote                 686832
# votes                    686832
# budget                   686832
# usa_gross_income         686832
# worlwide_gross_income    686832
# metascore                686832
# reviews_from_users       686832
# reviews_from_critics     686832
# year1                    686832
# year2                    686832
# year3                    686832
# dtype: int64

# %%
#df[df['year']=='TV Movie 2019']

# %%
df1['year'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c108035c2b31> in <module>
# ----> 1 df1['year'].astype(int)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df1[df1.notnull()]

# %%
df1.dtypes

# %%
df1[df1['year']=='TV Movie 2019']

# %%
df2.drop([0]) #i did this to check it would work.

# %%
Year = df1['year'].astype(int)

# %%
Year.head()

# %%
df1['Year'] = Year

# %%
df1.head()

# %%
df1.dtypes

# %%
#df1.drop(['Year'], axis=1,inplace = True)

# %%
df1.insert(5, 'Year', Year)

# %%
df1.head()

# %%
df1.drop(['year'], axis=1,inplace = True)

# %%
cols = list(df1.columns.values)
cols

# %%
df1.columns

# %%
df4= df1[['imdb_title_id', 'title', 'date_published', 
       'duration', 'avg_vote','country', 'language', 'director', 'Year', 'genre','writer',
       'production_company', 'actors','original_title', 'description',  'votes',
       'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
       'reviews_from_users', 'reviews_from_critics']]

# %%
df4.head()

# %%
df5 = df4.sort_values(by=['Year'], ascending= False).head(10)
df5

# %%
df6=df5.loc[84749:53592,:'genre']

# %%
df6.dtypes #to check what type of data type date_published is

# %%
df6['Year']=df6['Year'].apply(np.int64)

# %%
df6['year_check']=pd.DatetimeIndex(df6['date_published']).year

# %%
df6.head()

# %%
df6.drop('year__consitency_check', axis=1,  inplace= True)

# %%
df6.at[78575, 'Year'] = 2021
df6.at[84574, 'Year'] = 2019
df6

# %%
a=np.where(df6['Year'] != df6['year_check'], 'False','True')
#print ("inconsistency found in the year column for the movie" + df6['title'] )

# %%
a

# %%
df6['comparison column'] = np.where(df6['Year'] != df6['year_check'], 'False','True')

# %%
df6

# %%
df6['comparison_column'] = np.where(df6['Year'] != pd.DatetimeIndex(df6['date_published']).year, 'False','True')

# %%
df6

# %%
df6.memory_size()

# %%
df_sydneyHouses = pd.read_csv(r'/Users/chizzymba/Downloads/SydneyHousePrices.csv')

# %%
df_sydneyHouses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199504 entries, 0 to 199503
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        199504 non-null  object
#  1   Id          199504 non-null  int64
#  2   suburb      199504 non-null  object
#  3   postalCode  199504 non-null  int64
#  4   sellPrice   199504 non-null  int64
#  5   bed         199350 non-null  float64
#  6   bath        199504 non-null  int64
#  7   car         181353 non-null  float64
#  8   propType    199504 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 13.7+ MB

# %%
df_sydneyHouses.head()
# Out:
#          Date  Id        suburb  postalCode  sellPrice  bed  bath  car  \
# 0  2019-06-19   1  Avalon Beach        2107    1210000  4.0     2  2.0
# 1  2019-06-13   2  Avalon Beach        2107    2250000  4.0     3  4.0
# 2  2019-06-07   3   Whale Beach        2107    2920000  3.0     3  2.0
# 3  2019-05-28   4  Avalon Beach        2107    1530000  3.0     1  2.0
# 4  2019-05-22   5   Whale Beach        2107    8000000  5.0     4  4.0
#
#   propType
# 0    house
# 1    house
# 2    house
# 3    house
# 4    house

# %%
df_sydneyHouses.isnull().sum()
# Out:
# Date              0
# Id                0
# suburb            0
# postalCode        0
# sellPrice         0
# bed             154
# bath              0
# car           18151
# propType          0
# dtype: int64

# %%
df_sydneyHouses.groupby('suburb')['suburb'].agg('count')
# Out:
# suburb
# Abbotsbury     125
# Abbotsford     236
# Agnes Banks     47
# Airds           31
# Alexandria     760
#               ...
# Yarrawarrah     65
# Yellow Rock     51
# Yennora         32
# Yowie Bay      214
# Zetland        134
# Name: suburb, Length: 685, dtype: int64

# %%
 pd.Series(df_sydneyHouses['suburb'].unique()).to_frame()
# Out:
#                    0
# 0       Avalon Beach
# 1        Whale Beach
# 2    Bilgola Plateau
# 3         Clareville
# 4      Bilgola Beach
# ..               ...
# 680         Illawong
# 681            Menai
# 682           Bangor
# 683     Barden Ridge
# 684    Alfords Point
#
# [685 rows x 1 columns]

# %%
df_res1 = pd.read_csv(r'/Users/chizzymba/Downloads/two-stars-michelin-restaurants.csv')
df_res2 = pd.read_csv(r'/Users/chizzymba/Downloads/three-stars-michelin-restaurants.csv')
df_res3 = pd.read_csv(r'/Users/chizzymba/Downloads/one-star-michelin-restaurants.csv')

# %%
df_res1.head()
# Out:
#                                name  year  latitude  longitude      city  \
# 0                  SENNS.Restaurant  2019  47.83636   13.06389  Salzburg
# 1                            Ikarus  2019  47.79536   13.00695  Salzburg
# 2                       Mraz & Sohn  2019  48.23129   16.37637      Wien
# 3               Konstantin Filippou  2019  48.21056   16.37996      Wien
# 4  Silvio Nickol Gourmet Restaurant  2019  48.20558   16.37693      Wien
#
#     region zipCode         cuisine  price  \
# 0  Austria    5020        Creative  $$$$$
# 1  Austria    5020        Creative  $$$$$
# 2  Austria    1200        Creative  $$$$$
# 3  Austria    1010  Modern cuisine  $$$$$
# 4  Austria    1010  Modern cuisine  $$$$$
#
#                                                  url
# 0  https://guide.michelin.com/at/en/salzburg-regi...
# 1  https://guide.michelin.com/at/en/salzburg-regi...
# 2  https://guide.michelin.com/at/en/vienna/wien/r...
# 3  https://guide.michelin.com/at/en/vienna/wien/r...
# ...

# %%
df_res1.merge(df_res2, on = ('name', 'year','latitude','longitude','city','zipCode', 'cuisine','price','url'))
# Out:
# Empty DataFrame
# Columns: [name, year, latitude, longitude, city, region_x, zipCode, cuisine, price, url, region_y]
# Index: []

# %%
df_res=pd.concat([df_res1,df_res2,df_res3])

# %%
df_res.isnull().sum()
# Out:
# name           0
# year           0
# latitude       0
# longitude      0
# city           2
# region         0
# zipCode      194
# cuisine        0
# price        176
# url            0
# dtype: int64

# %%
df_res.to_csv(r'/Users/chizzymba/Downloads/archive.csv')

# %%
df_germany = pd.read_csv(r'/Users/chizzymba/Downloads/germany_housing_data_14.07.2020-1.csv')

# %%
df_germany.head()
# Out:
#    Unnamed: 0     Price               Type  Living_space    Lot  Usable_area  \
# 0           0  498000.0  Multiple dwelling        106.00  229.0          NaN
# 1           1  495000.0  Mid-terrace house        140.93  517.0        20.00
# 2           2  749000.0          Farmhouse        162.89   82.0        37.62
# 3           3  259000.0          Farmhouse        140.00  814.0          NaN
# 4           4  469000.0  Multiple dwelling        115.00  244.0          NaN
#
#       Free_of_Relation  Rooms  Bedrooms  Bathrooms  ...  \
# 0          01.10.2020     5.5       3.0        1.0  ...
# 1          01.01.2021     6.0       3.0        2.0  ...
# 2          01.07.2020     5.0       3.0        2.0  ...
# 3   nach Vereinbarung     4.0       NaN        2.0  ...
# 4              sofort     4.5       2.0        1.0  ...
#
#              Energy_source   Energy_certificate Energy_certificate_type  \
# 0                     Gas             available      demand certificate
# ...

# %%
df_germany.isnull().sum()
# Out:
# Unnamed: 0                    0
# Price                         0
# Type                        402
# Living_space                  0
# Lot                           0
# Usable_area                4984
# Free_of_Relation           3569
# Rooms                         0
# Bedrooms                   3674
# Bathrooms                  1801
# Floors                     2664
# Year_built                  694
# Furnishing_quality         2726
# Year_renovated             5203
# Condition                   323
# Heating                     584
# Energy_source              1227
# Energy_certificate          755
# Energy_certificate_type    3526
# Energy_consumption         8119
# Energy_efficiency_class    4819
# State                         1
# City                          1
# Place                       290
# Garages                    1960
# Garagetype                 1960
# dtype: int64

# %%
df_germany['State'].unique()
# Out:
# array(['Baden-Württemberg', 'Rheinland-Pfalz', 'Bayern', 'Hessen',
#        'Berlin', nan, 'Brandenburg', 'Bremen', 'Niedersachsen', 'Hamburg',
#        'Nordrhein-Westfalen', 'Mecklenburg-Vorpommern',
#        'Schleswig-Holstein', 'Saarland', 'Sachsen', 'Sachsen-Anhalt',
#        'Thüringen'], dtype=object)

# %%
df_uscompany = pd.read_csv(r'/Users/chizzymba/Downloads/us_companies.csv')

# %%
df_uscompany.head()
# Out:
#       company_name_id          company_name                          url  \
# 0  3-round-stones-inc  3 Round Stones, Inc.      http://3RoundStones.com
# 1    48-factoring-inc     48 Factoring Inc.  https://www.48factoring.com
# 2         5psolutions           5PSolutions          www.5psolutions.com
# 3      abt-associates        Abt Associates                 abtassoc.com
# 4              accela                Accela        http://www.accela.com
#
#    year_founded           city state country  zip_code full_time_employees  \
# 0        2010.0     Washington    DC      us   20004.0                1-10
# 1        2014.0   Philadelphia    PA      us   19087.0              51-200
# 2        2007.0        Fairfax    VA      us   22003.0                1-10
# 3        1965.0      Cambridge    MA      us    2138.0         1,001-5,000
# 4        1999.0      San Ramon    CA      us   94583.0           501-1,000
#
#   company_type  ...                                     business_model  \
# ...

# %%
df_uscompany['business_model'].unique()
# Out:
# array(['Business to Business, Business to Consumer',
#        'Business to Business',
#        'Business to Business, Business to Consumer, Business to Government',
#        nan, 'Business to Consumer', 'Business to Government',
#        'Business to Business, Business to Government',
#        'Business to Business, Business to Government, academia',
#        'Business to Consumer, Business to Government',
#        'Business to Business, Business to Consumer, ', 'nonprofit',
#        'Nonprofit',
#        'Business to Business, Business to Government, nonprofit',
#        'Business to Business, academia',
#        'Business to Business, Business to Consumer, Business to Government, ',
#        'Business to Government, Business to Nonprofit',
#        'Business to Business, nonprofit',
#        'Business to Consumer, Business to Government, nonprofit',
#        'Business to Government, ', 'Business to Government, nonprofit',
#        'academia',
# ...

# %%
df_uscompany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company_name_id      529 non-null    object
#  1   company_name         529 non-null    object
#  2   url                  529 non-null    object
#  3   year_founded         528 non-null    float64
#  4   city                 496 non-null    object
#  5   state                529 non-null    object
#  6   country              529 non-null    object
#  7   zip_code             492 non-null    float64
#  8   full_time_employees  500 non-null    object
#  9   company_type         513 non-null    object
#  10  company_category     526 non-null    object
#  11  revenue_source       519 non-null    object
#  12  business_model       453 non-null    object
#  13  social_impact        16 non-null     object
#  14  description          529 non-null    object
# ...

# %%
df_london=pd.read_csv('/Users/chizzymba/Downloads/London.csv')

# %%
df_london.head()
# Out:
#    Unnamed: 0  Property Name    Price        House Type  Area in sq ft  \
# 0           0    Queens Road  1675000             House           2716
# 1           1  Seward Street   650000  Flat / Apartment            814
# 2           2    Hotham Road   735000  Flat / Apartment            761
# 3           3   Festing Road  1765000             House           1986
# 4           4   Spencer Walk   675000  Flat / Apartment            700
#
#    No. of Bedrooms  No. of Bathrooms  No. of Receptions     Location  \
# 0                5                 5                  5    Wimbledon
# 1                2                 2                  2  Clerkenwell
# 2                2                 2                  2       Putney
# 3                4                 4                  4       Putney
# 4                2                 2                  2       Putney
#
#   City/County Postal Code
# 0      London    SW19 8NY
# 1      London    EC1V 3PA
# 2      London    SW15 1QL
# ...

# %%
print("It contains {} duplicates.".format(df_london.duplicated().sum()))
# Out:
# It contains 0 duplicates.

# %%
print("It contains {} duplicates.".format(df_uscompany.duplicated().sum()))
# Out:
# It contains 0 duplicates.

# %%
print("It contains {} duplicates.".format(df_germany.duplicated().sum()))
# Out:
# It contains 0 duplicates.

# %%
df_india=pd.read_csv(r'/Users/chizzymba/Downloads/Bengaluru_House_Data.csv')

# %%
df_india.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00
