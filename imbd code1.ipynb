# %%
import pandas as pd
import os
import numpy as np

# %%
print(os.path.exists('/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/IMDb movies.csv'))
# Out:
# True

# %%
df=pd.read_csv(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/IMDb movies.csv')
# Out:
# /Users/chizzymba/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head() #view of what the dataset looks like
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
df1 = pd.read_csv(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/IMDb movies.csv')
# Out:
# /Users/chizzymba/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2= pd.read_csv(r'/Users/chizzymba/Desktop/data science/jose portila course/Refactored_Py_DS_ML_Bootcamp-master/IMDb ratings.csv')

# %%
df2.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                 13.0                     4.5                  4.0
# 1                 23.0                     6.6                 14.0
# 2                  4.0                     6.8                  7.0
# 3                 14.0                     6.1                 21.0
# 4                 82.0                     7.4                 77.0
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    5.7                  34.0               6.4
# 1                    6.4                  66.0               6.0
# 2                    5.4                  32.0               6.2
# 3                    4.9                  57.0               5.5
# 4                    6.9                 139.0               7.0
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# 0             51.0                   6.0                 70.0
# 1             96.0                   6.2                331.0
# 2             31.0                   5.9                123.0
# 3            207.0                   4.7                105.0
# 4            488.0                   7.0               1166.0
#
# [5 rows x 49 columns]

# %%
new_df = pd.merge(df1, df2, on = 'imdb_title_id') #merging the two datasets.

# %%
df.dtypes #checking for the data types within the data set
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
df.memory_usage()
# Out:
# Index                       128
# imdb_title_id            686840
# title                    686840
# original_title           686840
# year                     686840
# date_published           686840
# genre                    686840
# duration                 686840
# country                  686840
# language                 686840
# director                 686840
# writer                   686840
# production_company       686840
# actors                   686840
# description              686840
# avg_vote                 686840
# votes                    686840
# budget                   686840
# usa_gross_income         686840
# worlwide_gross_income    686840
# metascore                686840
# reviews_from_users       686840
# reviews_from_critics     686840
# dtype: int64

# %%
df['year'].unique() 
#this identifies one inncorrect record that has to be fixed either by replacing the record or dropping the row
# Out:
# array([1894, 1906, 1911, 1912, 1919, 1913, 1914, 1915, 1916, 1917, 1918,
#        1920, 1921, 1924, 1922, 1923, 1925, 1926, 1935, 1927, 1928, 1983,
#        1929, 1930, 1932, 1931, 1937, 1938, 1933, 1934, 1936, 1940, 1939,
#        1942, 1943, 1941, 1948, 1944, 2001, 1946, 1945, 1947, 1973, 1949,
#        1950, 1952, 1951, 1962, 1953, 1954, 1955, 1961, 1956, 1958, 1957,
#        1959, 1960, 1963, 1965, 1971, 1964, 1966, 1968, 1967, 1969, 1976,
#        1970, 1979, 1972, 1981, 1978, 2000, 1989, 1975, 1974, 1986, 1990,
#        2018, 1977, 1982, 1980, 1993, 1984, 1985, 1988, 1987, 2005, 1991,
#        2002, 1994, 1992, 1995, 2017, 1997, 1996, 2006, 1999, 1998, 2007,
#        2008, 2003, 2004, 2010, 2009, 2011, 2013, 2012, 2016, 2015, 2014,
#        2019, 2020, '2012', '2015', '2009', '2013', '2018', '2014', '2017',
#        '2011', '2016', '1981', '1975', '2010', '1984', '2007', '2006',
#        '2001', '2004', '1979', '2019', '1967', '1978', '2003', '2005',
#        '1969', '1990', '1983', '2002', '1996', '2008', '1995', '1999',
#        '1974', '1993', '1998', '1989', '2020', '1966', '1956', '1962',
#        '1985', '2000', '1971', '1970', '1986', '1930', '1976', '1982',
#        '1992', '1963', '1994', '1964', '1997', '1987', '1980',
#        'TV Movie 2019', '1988'], dtype=object)

# %%
df[df['year']=='TV Movie 2019'] #to identify the unique id of the row with the problem
# Out:
#       imdb_title_id          title original_title           year  \
# 83917     tt8206668  Bad Education  Bad Education  TV Movie 2019
#
#       date_published                     genre  duration country language  \
# 83917  TV Movie 2019  Biography, Comedy, Crime       108     USA  English
#
#           director  ...                                             actors  \
# 83917  Cory Finley  ...  Hugh Jackman, Ray Romano, Welker White, Alliso...
#
#                                              description avg_vote  votes  \
# 83917  The beloved superintendent of New York's Rosly...      7.1  23973
#
#        budget  usa_gross_income worlwide_gross_income metascore  \
# 83917     NaN               NaN                   NaN      79.0
#
#       reviews_from_users  reviews_from_critics
# 83917              135.0                  98.0
#
# [1 rows x 22 columns]

# %%
df.drop(83917, axis=0, inplace= True) #dropping the row with the incorrect record

# %%
df['year1']=df['year'].apply(np.int64)
df['year2']=df['year'].apply(np.float64)
df['year3']=df['year'].apply(np.str)
df.dtypes
#brief test to see how the memory is affected by differnt data types of the same size
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# year1                      int64
# year2                    float64
# year3                     object
# dtype: object

# %%
df.memory_usage() #clearly no difference in this case
# Out:
# Index                    686832
# imdb_title_id            686832
# title                    686832
# original_title           686832
# year                     686832
# date_published           686832
# genre                    686832
# duration                 686832
# country                  686832
# language                 686832
# director                 686832
# writer                   686832
# production_company       686832
# actors                   686832
# description              686832
# avg_vote                 686832
# votes                    686832
# budget                   686832
# usa_gross_income         686832
# worlwide_gross_income    686832
# metascore                686832
# reviews_from_users       686832
# reviews_from_critics     686832
# year1                    686832
# year2                    686832
# year3                    686832
# dtype: int64

# %%
df['year'].astype(int)
# Out:
# 0        1894
# 1        1906
# 2        1911
# 3        1912
# 4        1911
#          ...
# 85850    2020
# 85851    2020
# 85852    2019
# 85853    2019
# 85854    2019
# Name: year, Length: 85854, dtype: int64

# %%
df[df.notnull()]
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title date_published  Year  \
# 0                          Miss Jerry     1894-10-09  1894
# 1         The Story of the Kelly Gang     1906-12-26  1906
# 2                      Den sorte drøm     1911-08-19  1911
# 3                           Cleopatra     1912-11-13  1912
# 4                           L'Inferno     1911-03-06  1911
# ...                               ...            ...   ...
# 85850                         Le lion     2020-01-29  2020
# 85851  De Beentjes van Sint-Hildegard     2020-02-13  2020
# 85852       Padmavyuhathile Abhimanyu     2019-03-08  2019
# 85853               Sokagin Çocuklari     2019-03-15  2019
# 85854      La vida sense la Sara Amat     2020-02-05  2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ... votes   budget  \
# 0                          Alexander Black  ...   154      NaN
# 1                             Charles Tait  ...   589   $ 2250
# 2                                Urban Gad  ...   188      NaN
# 3                       Charles L. Gaskill  ...   446  $ 45000
# 4      Francesco Bertolini, Adolfo Padovan  ...  2237      NaN
# ...                                    ...  ...   ...      ...
# 85850               Ludovic Colbeau-Justin  ...   398      NaN
# 85851                      Johan Nijenhuis  ...   724      NaN
# 85852                      Vineesh Aaradya  ...   265      NaN
# 85853                    Ahmet Faik Akinci  ...   194      NaN
# 85854                            Laura Jou  ...   102      NaN
#
#       usa_gross_income worlwide_gross_income  metascore  reviews_from_users  \
# 0                  NaN                   NaN        NaN                 1.0
# 1                  NaN                   NaN        NaN                 7.0
# 2                  NaN                   NaN        NaN                 5.0
# 3                  NaN                   NaN        NaN                25.0
# 4                  NaN                   NaN        NaN                31.0
# ...                ...                   ...        ...                 ...
# 85850              NaN             $ 3507171        NaN                 NaN
# 85851              NaN             $ 7299062        NaN                 6.0
# 85852              NaN                   NaN        NaN                 NaN
# 85853              NaN                $ 2833        NaN                 NaN
# 85854              NaN               $ 59794        NaN                 NaN
#
#       reviews_from_critics year1   year2  year3
# 0                      2.0  1894  1894.0   1894
# 1                      7.0  1906  1906.0   1906
# 2                      2.0  1911  1911.0   1911
# 3                      3.0  1912  1912.0   1912
# 4                     14.0  1911  1911.0   1911
# ...                    ...   ...     ...    ...
# 85850                  4.0  2020  2020.0   2020
# 85851                  4.0  2020  2020.0   2020
# 85852                  NaN  2019  2019.0   2019
# 85853                  NaN  2019  2019.0   2019
# 85854                  2.0  2019  2019.0   2019
#
# [85854 rows x 25 columns]

# %% [markdown]
# reformating the year colum to int

# %%
Year = df['year'].astype(int)

# %%
Year.head()
# Out:
# 0    1894
# 1    1906
# 2    1911
# 3    1912
# 4    1911
# Name: year, dtype: int64

# %%
df.insert(5, 'Year', Year)

# %%
df.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published  Year                      genre  duration  \
# 0  1894     1894-10-09  1894                    Romance        45
# 1  1906     1906-12-26  1906    Biography, Crime, Drama        70
# 2  1911     1911-08-19  1911                      Drama        53
# 3  1912     1912-11-13  1912             Drama, History       100
# 4  1911     1911-03-06  1911  Adventure, Drama, Fantasy        68
#
#             country language  ... votes   budget usa_gross_income  \
# 0               USA     None  ...   154      NaN              NaN
# 1         Australia     None  ...   589   $ 2250              NaN
# 2  Germany, Denmark      NaN  ...   188      NaN              NaN
# 3               USA  English  ...   446  $ 45000              NaN
# 4             Italy  Italian  ...  2237      NaN              NaN
#
#   worlwide_gross_income metascore  reviews_from_users  reviews_from_critics  \
# 0                   NaN       NaN                 1.0                   2.0
# 1                   NaN       NaN                 7.0                   7.0
# 2                   NaN       NaN                 5.0                   2.0
# 3                   NaN       NaN                25.0                   3.0
# 4                   NaN       NaN                31.0                  14.0
#
#   year1   year2 year3
# 0  1894  1894.0  1894
# 1  1906  1906.0  1906
# 2  1911  1911.0  1911
# 3  1912  1912.0  1912
# 4  1911  1911.0  1911
#
# [5 rows x 26 columns]

# %%
#df.drop(['year'], axis=1,inplace = True)

# %%
cols = list(df1.columns.values)
cols
# Out:
# ['imdb_title_id',
#  'title',
#  'original_title',
#  'year',
#  'date_published',
#  'genre',
#  'duration',
#  'country',
#  'language',
#  'director',
#  'writer',
#  'production_company',
#  'actors',
#  'description',
#  'avg_vote',
#  'votes',
#  'budget',
#  'usa_gross_income',
#  'worlwide_gross_income',
#  'metascore',
#  'reviews_from_users',
#  'reviews_from_critics']

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'Year', 'genre', 'duration', 'country', 'language', 'director',
#        'writer', 'production_company', 'actors', 'description', 'avg_vote',
#        'votes', 'budget', 'usa_gross_income', 'worlwide_gross_income',
#        'metascore', 'reviews_from_users', 'reviews_from_critics', 'year1',
#        'year2', 'year3'],
#       dtype='object')

# %%
df4= df[['imdb_title_id', 'title', 'date_published', 
       'duration', 'avg_vote','country', 'language', 'director', 'Year', 'genre','writer',
       'production_company', 'actors','original_title', 'description',  'votes',
       'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
       'reviews_from_users', 'reviews_from_critics']]
# to remove the duplicate year column and leave only the corect formated Year column

# %%
df4.head()
# Out:
#   imdb_title_id                        title date_published  duration  \
# 0     tt0000009                   Miss Jerry     1894-10-09        45
# 1     tt0000574  The Story of the Kelly Gang     1906-12-26        70
# 2     tt0001892               Den sorte drøm     1911-08-19        53
# 3     tt0002101                    Cleopatra     1912-11-13       100
# 4     tt0002130                    L'Inferno     1911-03-06        68
#
#    avg_vote           country language                             director  \
# 0       5.9               USA     None                      Alexander Black
# 1       6.1         Australia     None                         Charles Tait
# 2       5.8  Germany, Denmark      NaN                            Urban Gad
# 3       5.2               USA  English                   Charles L. Gaskill
# 4       7.0             Italy  Italian  Francesco Bertolini, Adolfo Padovan
#
#    Year                      genre  ...  \
# 0  1894                    Romance  ...
# 1  1906    Biography, Crime, Drama  ...
# 2  1911                      Drama  ...
# 3  1912             Drama, History  ...
# 4  1911  Adventure, Drama, Fantasy  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                 original_title  \
# 0                   Miss Jerry
# 1  The Story of the Kelly Gang
# 2               Den sorte drøm
# 3                    Cleopatra
# 4                    L'Inferno
#
#                                          description votes   budget  \
# 0  The adventures of a female reporter in the 1890s.   154      NaN
# 1  True story of notorious Australian outlaw Ned ...   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %% [markdown]
# sorting the dataset by year to get the first 10 records in 2020 to which i introduced some intentional errors and used within the chapter 3 of thesis

# %%
df5 = df4.sort_values(by=['Year'], ascending= False).head(10)
df5
# Out:
#       imdb_title_id                       title date_published  duration  \
# 84749     tt8810394      The Point of No Return     2020-06-16       110
# 71937     tt3612126                  The Grudge     2020-03-05        94
# 71828     tt3580692               Diverted Eden     2020-03-01       110
# 53613    tt10816484                   18 regali     2020-01-02       115
# 53612    tt10814876  7 ore per farti innamorare     2020-04-20        93
# 78575     tt5747714                     Unbound     2020-02-07        97
# 53598    tt10806028               Agir Romantik     2020-02-14        97
# 84574     tt8675288     Il mio nome è Imp@vido_     2020-08-14        89
# 75762     tt4789618                  Still Here     2020-08-28        99
# 53592    tt10801196             Pressure Cooker     2020-02-21       135
#
#        avg_vote      country language            director  Year  \
# 84749       3.0           UK      NaN        Rick Roberts  2020
# 71937       4.2  USA, Canada  English       Nicolas Pesce  2020
# 71828       4.2          USA  English  Prince Bagdasarian  2020
# 53613       6.7        Italy  Italian     Francesco Amato  2020
# 53612       5.9        Italy  Italian   Giampaolo Morelli  2020
# 78575       4.5          USA  English       Steve Rahaman  2020
# 53598       8.0       Turkey  Turkish    Deniz Denizciler  2020
# 84574       4.8       Canada  English        Cory Edwards  2020
# 75762       7.0          USA  English          Vlad Feier  2020
# 53592       6.4        India   Telugu       Sujoi, Sushil  2020
#
#                            genre  ...  \
# 84749                        War  ...
# 71937            Horror, Mystery  ...
# 71828       Action, Crime, Drama  ...
# 53613                      Drama  ...
# 53612                     Comedy  ...
# 78575       Action, Crime, Drama  ...
# 53598     Comedy, Drama, Romance  ...
# 84574  Animation, Comedy, Family  ...
# 75762     Crime, Drama, Thriller  ...
# 53592      Comedy, Drama, Family  ...
#
#                                                   actors  \
# 84749  Mhairi Calvey, Chris Wilson, Justin Hayward, J...
# 71937  Tara Westwood, Junko Bailey, David Lawrence Br...
# 71828  Scout Taylor-Compton, Michael Urie, Najarra To...
# 53613  Vittoria Puccini, Benedetta Porcaroli, Edoardo...
# 53612  Giampaolo Morelli, Serena Rossi, Diana Del Buf...
# 78575  Daniel O'Shea, Debra Toscano, Michael Robert A...
# 53598  Onur Tuna, Tuvana Türkay, Durul Bazan, Ismail ...
# 84574  Yara Shahidi, Miles Robbins, Miguel, Jadakiss,...
# 75762  Johnny Whitworth, Zazie Beetz, Afton Williamso...
# 53592  Abhinaya, Anil, Preethi Asrani, Babloo, Tanike...
#
#                    original_title  \
# 84749      The Point of No Return
# 71937                  The Grudge
# 71828               Diverted Eden
# 53613                   18 regali
# 53612  7 ore per farti innamorare
# 78575                     Unbound
# 53598               Agir Romantik
# 84574                    Fearless
# 75762                  Still Here
# 53592             Pressure Cooker
#
#                                              description  votes       budget  \
# 84749  A dwindling group of German soldiers battle to...    159          NaN
# 71937  A house is cursed by a vengeful ghost that doo...  17156   $ 10000000
# 71828  After his young daughter is kidnapped, a war h...    402          NaN
# 53613  Inspired by the extraordinary story of Elisa G...   2355  EUR 2500000
# 53612  Valeria, a beautiful and determined woman disi...    617  EUR 1200000
# 78575  Set in a sleepy town in New Orleans, a family ...    182      $ 80000
# 53598                                                NaN    357          NaN
# 84574  A teen gamer is forced to level up to full-tim...    649          NaN
# 75762  A New York journalist who gets assigned the st...    205          NaN
# 53592  This is a new age family drama entertainer. Th...    223          NaN
#
#        usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 84749               NaN                   NaN       NaN               16.0
# 71937        $ 21221803            $ 49511319      41.0              525.0
# 71828               NaN                   NaN       NaN               33.0
# 53613               NaN             $ 3486375       NaN               14.0
# 53612               NaN                $ 3757       NaN                1.0
# 78575               NaN                   NaN       NaN               11.0
# 53598               NaN              $ 193612       NaN                7.0
# 84574               NaN                   NaN       NaN               16.0
# 75762               NaN                   NaN       NaN                7.0
# 53592               NaN                   NaN       NaN               18.0
#
#        reviews_from_critics
# 84749                   1.0
# 71937                 178.0
# 71828                   2.0
# 53613                  20.0
# 53612                   NaN
# 78575                   NaN
# 53598                   NaN
# 84574                  13.0
# 75762                  12.0
# 53592                   1.0
#
# [10 rows x 22 columns]

# %%
df6=df5.loc[84749:53592,:'genre']

# %%
df6.dtypes #to check what type of data type date_published is
# Out:
# imdb_title_id      object
# title              object
# date_published     object
# duration            int64
# avg_vote          float64
# country            object
# language           object
# director           object
# Year                int64
# genre              object
# dtype: object

# %%
df6['Year']=df6['Year'].apply(np.int64)

# %%
df6['year_check']=pd.DatetimeIndex(df6['date_published']).year

# %%
df6.head()
# Out:
#       imdb_title_id                       title date_published  duration  \
# 84749     tt8810394      The Point of No Return     2020-06-16       110
# 71937     tt3612126                  The Grudge     2020-03-05        94
# 71828     tt3580692               Diverted Eden     2020-03-01       110
# 53613    tt10816484                   18 regali     2020-01-02       115
# 53612    tt10814876  7 ore per farti innamorare     2020-04-20        93
#
#        avg_vote      country language            director  Year  \
# 84749       3.0           UK      NaN        Rick Roberts  2020
# 71937       4.2  USA, Canada  English       Nicolas Pesce  2020
# 71828       4.2          USA  English  Prince Bagdasarian  2020
# 53613       6.7        Italy  Italian     Francesco Amato  2020
# 53612       5.9        Italy  Italian   Giampaolo Morelli  2020
#
#                       genre  year_check
# 84749                   War        2020
# 71937       Horror, Mystery        2020
# 71828  Action, Crime, Drama        2020
# 53613                 Drama        2020
# 53612                Comedy        2020

# %%
df6.drop('year__consitency_check', axis=1,  inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-b765d7f60839> in <module>
# ----> 1 df6.drop('year__consitency_check', axis=1,  inplace= True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['year__consitency_check'] not found in axis"

# %%
df6.at[78575, 'Year'] = 2021
df6.at[84574, 'Year'] = 2019
df6
# Out:
#       imdb_title_id                       title date_published  duration  \
# 84749     tt8810394      The Point of No Return     2020-06-16       110
# 71937     tt3612126                  The Grudge     2020-03-05        94
# 71828     tt3580692               Diverted Eden     2020-03-01       110
# 53613    tt10816484                   18 regali     2020-01-02       115
# 53612    tt10814876  7 ore per farti innamorare     2020-04-20        93
# 78575     tt5747714                     Unbound     2020-02-07        97
# 53598    tt10806028               Agir Romantik     2020-02-14        97
# 84574     tt8675288     Il mio nome è Imp@vido_     2020-08-14        89
# 75762     tt4789618                  Still Here     2020-08-28        99
# 53592    tt10801196             Pressure Cooker     2020-02-21       135
#
#        avg_vote      country language            director  Year  \
# 84749       3.0           UK      NaN        Rick Roberts  2020
# 71937       4.2  USA, Canada  English       Nicolas Pesce  2020
# 71828       4.2          USA  English  Prince Bagdasarian  2020
# 53613       6.7        Italy  Italian     Francesco Amato  2020
# 53612       5.9        Italy  Italian   Giampaolo Morelli  2020
# 78575       4.5          USA  English       Steve Rahaman  2021
# 53598       8.0       Turkey  Turkish    Deniz Denizciler  2020
# 84574       4.8       Canada  English        Cory Edwards  2019
# 75762       7.0          USA  English          Vlad Feier  2020
# 53592       6.4        India   Telugu       Sujoi, Sushil  2020
#
#                            genre  year_check
# 84749                        War        2020
# 71937            Horror, Mystery        2020
# 71828       Action, Crime, Drama        2020
# 53613                      Drama        2020
# 53612                     Comedy        2020
# 78575       Action, Crime, Drama        2020
# 53598     Comedy, Drama, Romance        2020
# 84574  Animation, Comedy, Family        2020
# 75762     Crime, Drama, Thriller        2020
# 53592      Comedy, Drama, Family        2020

# %%
a=np.where(df6['Year'] != df6['year_check'], 'False','True')
#print ("inconsistency found in the year column for the movie" + df6['title'] )

# %%
a
# Out:
# array(['True', 'True', 'True', 'True', 'True', 'False', 'True', 'False',
#        'True', 'True'], dtype='<U5')

# %%
df6['comparison column'] = np.where(df6['Year'] != df6['year_check'], 'False','True')

# %%
df6
# Out:
#       imdb_title_id                       title date_published  duration  \
# 84749     tt8810394      The Point of No Return     2020-06-16       110
# 71937     tt3612126                  The Grudge     2020-03-05        94
# 71828     tt3580692               Diverted Eden     2020-03-01       110
# 53613    tt10816484                   18 regali     2020-01-02       115
# 53612    tt10814876  7 ore per farti innamorare     2020-04-20        93
# 78575     tt5747714                     Unbound     2020-02-07        97
# 53598    tt10806028               Agir Romantik     2020-02-14        97
# 84574     tt8675288     Il mio nome è Imp@vido_     2020-08-14        89
# 75762     tt4789618                  Still Here     2020-08-28        99
# 53592    tt10801196             Pressure Cooker     2020-02-21       135
#
#        avg_vote      country language            director  Year  \
# 84749       3.0           UK      NaN        Rick Roberts  2020
# 71937       4.2  USA, Canada  English       Nicolas Pesce  2020
# 71828       4.2          USA  English  Prince Bagdasarian  2020
# 53613       6.7        Italy  Italian     Francesco Amato  2020
# 53612       5.9        Italy  Italian   Giampaolo Morelli  2020
# 78575       4.5          USA  English       Steve Rahaman  2021
# 53598       8.0       Turkey  Turkish    Deniz Denizciler  2020
# 84574       4.8       Canada  English        Cory Edwards  2019
# 75762       7.0          USA  English          Vlad Feier  2020
# 53592       6.4        India   Telugu       Sujoi, Sushil  2020
#
#                            genre  year_check comparison column
# 84749                        War        2020              True
# 71937            Horror, Mystery        2020              True
# 71828       Action, Crime, Drama        2020              True
# 53613                      Drama        2020              True
# 53612                     Comedy        2020              True
# 78575       Action, Crime, Drama        2020             False
# 53598     Comedy, Drama, Romance        2020              True
# 84574  Animation, Comedy, Family        2020             False
# 75762     Crime, Drama, Thriller        2020              True
# 53592      Comedy, Drama, Family        2020              True

# %%
df6['comparison_column'] = np.where(df6['Year'] != pd.DatetimeIndex(df6['date_published']).year, 'False','True')

# %%
df6
# Out:
#       imdb_title_id                       title date_published  duration  \
# 84749     tt8810394      The Point of No Return     2020-06-16       110
# 71937     tt3612126                  The Grudge     2020-03-05        94
# 71828     tt3580692               Diverted Eden     2020-03-01       110
# 53613    tt10816484                   18 regali     2020-01-02       115
# 53612    tt10814876  7 ore per farti innamorare     2020-04-20        93
# 78575     tt5747714                     Unbound     2020-02-07        97
# 53598    tt10806028               Agir Romantik     2020-02-14        97
# 84574     tt8675288     Il mio nome è Imp@vido_     2020-08-14        89
# 75762     tt4789618                  Still Here     2020-08-28        99
# 53592    tt10801196             Pressure Cooker     2020-02-21       135
#
#        avg_vote      country language            director  Year  \
# 84749       3.0           UK      NaN        Rick Roberts  2020
# 71937       4.2  USA, Canada  English       Nicolas Pesce  2020
# 71828       4.2          USA  English  Prince Bagdasarian  2020
# 53613       6.7        Italy  Italian     Francesco Amato  2020
# 53612       5.9        Italy  Italian   Giampaolo Morelli  2020
# 78575       4.5          USA  English       Steve Rahaman  2021
# 53598       8.0       Turkey  Turkish    Deniz Denizciler  2020
# 84574       4.8       Canada  English        Cory Edwards  2019
# 75762       7.0          USA  English          Vlad Feier  2020
# 53592       6.4        India   Telugu       Sujoi, Sushil  2020
#
#                            genre  year_check comparison column  \
# 84749                        War        2020              True
# 71937            Horror, Mystery        2020              True
# 71828       Action, Crime, Drama        2020              True
# 53613                      Drama        2020              True
# 53612                     Comedy        2020              True
# 78575       Action, Crime, Drama        2020             False
# 53598     Comedy, Drama, Romance        2020              True
# 84574  Animation, Comedy, Family        2020             False
# 75762     Crime, Drama, Thriller        2020              True
# 53592      Comedy, Drama, Family        2020              True
#
#       comparison_column
# 84749              True
# 71937              True
# 71828              True
# 53613              True
# 53612              True
# 78575             False
# 53598              True
# 84574             False
# 75762              True
# 53592              True
